# %% [markdown]
# ## This is a Lab Notebook ##
# - This is a test version

# %%
for i in range( 10 ) : print( i )

# %%
import numpy as np 
import seaborn as sns

# %%
arr = np.array([1,2,3,3,4,5,6,7,8,9,1,1,2,4,4,3,6,5])

# %%
sns.displot( arr )
